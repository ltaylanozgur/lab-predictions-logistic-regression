# %%
# prep: import modules and get pwd
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import sklearn
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

import pymysql
from sqlalchemy import create_engine
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %% [markdown]
# ## Create a query or queries to extract the information you think may be relevant for building the prediction model. It should include some film features and some rental features. Use the data from 2005.
#
# ## Read the data into a Pandas dataframe.

# %%
# get the data
connection_string = 'mysql+pymysql://root:' + password + '@localhost/sakila'
engine = create_engine(connection_string)

query = '''SELECT * FROM sakila.film f
JOIN sakila.inventory i USING (film_id)
JOIN sakila.rental fa USING (inventory_id)
JOIN sakila.film_category fc USING (film_id)
JOIN sakila.category c USING (category_id)
JOIN sakila.payment p USING (rental_id);'''

sakila = pd.read_sql_query(query, engine)
sakila.head()
# Out:
#    rental_id  category_id  film_id  inventory_id         title  \
# 0      10895            1       19            93  AMADEUS HOLY
# 1      12268            1       19            93  AMADEUS HOLY
# 2       3150            1       19            94  AMADEUS HOLY
# 3       5072            1       19            94  AMADEUS HOLY
# 4       9080            1       19            94  AMADEUS HOLY
#
#                                          description  release_year  \
# 0  A Emotional Display of a Pioneer And a Technic...          2006
# 1  A Emotional Display of a Pioneer And a Technic...          2006
# 2  A Emotional Display of a Pioneer And a Technic...          2006
# 3  A Emotional Display of a Pioneer And a Technic...          2006
# 4  A Emotional Display of a Pioneer And a Technic...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                6         0.99     113
# 1            1                 None                6         0.99     113
# 2            1                 None                6         0.99     113
# 3            1                 None                6         0.99     113
# 4            1                 None                6         0.99     113
#
#    replacement_cost rating                               special_features  \
# 0             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 1             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 2             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 3             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 4             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
#
#           last_update  store_id         last_update         rental_date  \
# 0 2006-02-15 05:03:42         1 2006-02-15 05:09:17 2005-08-02 01:16:59
# 1 2006-02-15 05:03:42         1 2006-02-15 05:09:17 2005-08-18 04:26:54
# 2 2006-02-15 05:03:42         1 2006-02-15 05:09:17 2005-06-20 20:35:28
# 3 2006-02-15 05:03:42         1 2006-02-15 05:09:17 2005-07-09 05:01:58
# 4 2006-02-15 05:03:42         1 2006-02-15 05:09:17 2005-07-30 08:02:39
#
#    customer_id         return_date  staff_id         last_update  \
# 0           77 2005-08-03 02:41:59         2 2006-02-15 21:30:53
# 1           39 2005-08-23 06:40:54         2 2006-02-15 21:30:53
# 2           34 2005-06-26 01:01:28         1 2006-02-15 21:30:53
# 3          254 2005-07-18 08:17:58         2 2006-02-15 21:30:53
# 4          276 2005-08-06 12:02:39         1 2006-02-15 21:30:53
#
#           last_update    name         last_update  payment_id  customer_id  \
# 0 2006-02-15 05:07:09  Action 2006-02-15 04:46:27        2104           77
# 1 2006-02-15 05:07:09  Action 2006-02-15 04:46:27        1093           39
# 2 2006-02-15 05:07:09  Action 2006-02-15 04:46:27         930           34
# 3 2006-02-15 05:07:09  Action 2006-02-15 04:46:27        6848          254
# 4 2006-02-15 05:07:09  Action 2006-02-15 04:46:27        7479          276
#
#    staff_id  amount        payment_date         last_update
# 0         1    0.99 2005-08-02 01:16:59 2006-02-15 22:12:50
# 1         2    0.99 2005-08-18 04:26:54 2006-02-15 22:12:38
# 2         1    0.99 2005-06-20 20:35:28 2006-02-15 22:12:36
# 3         1    3.99 2005-07-09 05:01:58 2006-02-15 22:14:52
# 4         1    1.99 2005-07-30 08:02:39 2006-02-15 22:15:16

# %%
sakila.isna().sum() # NaN values each column
# Out:
# rental_id                   0
# category_id                 0
# film_id                     0
# inventory_id                0
# title                       0
# description                 0
# release_year                0
# language_id                 0
# original_language_id    16044
# rental_duration             0
# rental_rate                 0
# length                      0
# replacement_cost            0
# rating                      0
# special_features            0
# last_update                 0
# store_id                    0
# last_update                 0
# rental_date                 0
# customer_id                 0
# return_date               183
# staff_id                    0
# last_update                 0
# last_update                 0
# name                        0
# last_update                 0
# payment_id                  0
# customer_id                 0
# staff_id                    0
# amount                      0
# payment_date                0
# last_update                 0
# dtype: int64

# %%
sakila.shape
# Out:
# (16044, 32)

# %%
# convert rental_date to datetime
sakila['rental_date'] = pd.to_datetime(sakila['rental_date'], errors='coerce')

# %% [markdown]
# ## Create a query to get the list of films and a boolean indicating if it was rented last month (May 2005). This would be our target variable.

# %%
# set may_target column
sakila['may_target'] = pd.DatetimeIndex(sakila['rental_date']).month

# %%
# may_target is the target.
def boolean(x):
    if x==5:
        return 1
    else:
        return 0

sakila['may_target'] = list(map(boolean, sakila['may_target']))

# %%
sakila['may_target'].value_counts(dropna=False)
# Out:
# 7    6709
# 8    5686
# 6    2311
# 5    1156
# 2     182
# Name: may_target, dtype: int64

# %%
# set duration_of_rental column

sakila['duration_of_rental'] = (sakila['return_date'] - sakila['rental_date'])

sakila.head() # This returns 184 NaTs in the new column

sum(sakila['duration_of_rental'].isna())

# Replace the NaNs with the column median 

time_median = sakila['duration_of_rental'].median()
time_median
sakila['duration_of_rental'] = sakila['duration_of_rental'].replace({np.nan: time_median}).dt.days

# %%
sakila.dtypes
# Out:
# rental_id                        int64
# category_id                      int64
# film_id                          int64
# inventory_id                     int64
# title                           object
# description                     object
# release_year                     int64
# language_id                      int64
# original_language_id            object
# rental_duration                  int64
# rental_rate                    float64
# length                           int64
# replacement_cost               float64
# rating                          object
# special_features                object
# last_update             datetime64[ns]
# store_id                         int64
# last_update             datetime64[ns]
# rental_date             datetime64[ns]
# customer_id                      int64
# return_date             datetime64[ns]
# staff_id                         int64
# last_update             datetime64[ns]
# last_update             datetime64[ns]
# name                            object
# last_update             datetime64[ns]
# payment_id                       int64
# customer_id                      int64
# staff_id                         int64
# amount                         float64
# payment_date            datetime64[ns]
# last_update             datetime64[ns]
# may_target                       int64
# duration_of_rental               int64
# dtype: object

# %%
sakila.shape
# Out:
# (16044, 34)

# %%
sakila = sakila.drop_duplicates()
sakila.shape
# Out:
# (16044, 34)

# %%
sakila['special_features'].unique()
# Out:
# array(['Commentaries,Deleted Scenes,Behind the Scenes',
#        'Commentaries,Behind the Scenes',
#        'Trailers,Commentaries,Deleted Scenes', 'Trailers,Commentaries',
#        'Deleted Scenes', 'Trailers,Commentaries,Behind the Scenes',
#        'Commentaries,Deleted Scenes', 'Behind the Scenes', 'Trailers',
#        'Deleted Scenes,Behind the Scenes',
#        'Trailers,Deleted Scenes,Behind the Scenes',
#        'Trailers,Commentaries,Deleted Scenes,Behind the Scenes',
#        'Trailers,Behind the Scenes', 'Commentaries',
#        'Trailers,Deleted Scenes'], dtype=object)

# %%
sakila.describe()
# Out:
#           rental_id   category_id       film_id  inventory_id  release_year  \
# count  16044.000000  16044.000000  16044.000000  16044.000000       16044.0
# mean    8025.371478      8.363999    501.108888   2291.842558        2006.0
# std     4632.777249      4.650700    288.513529   1322.210643           0.0
# min        1.000000      1.000000      1.000000      1.000000        2006.0
# 25%     4013.750000      4.000000    255.000000   1154.000000        2006.0
# 50%     8025.500000      8.000000    496.000000   2291.000000        2006.0
# 75%    12037.250000     13.000000    753.000000   3433.000000        2006.0
# max    16049.000000     16.000000   1000.000000   4581.000000        2006.0
#
#        language_id  rental_duration   rental_rate        length  \
# count      16044.0      16044.00000  16044.000000  16044.000000
# mean           1.0          4.93549      2.942630    114.971080
# std            0.0          1.40169      1.649678     40.102347
# min            1.0          3.00000      0.990000     46.000000
# 25%            1.0          4.00000      0.990000     81.000000
# 50%            1.0          5.00000      2.990000    114.000000
# 75%            1.0          6.00000      4.990000    148.000000
# max            1.0          7.00000      4.990000    185.000000
#
#        replacement_cost      store_id   customer_id      staff_id  \
# count      16044.000000  16044.000000  16044.000000  16044.000000
# mean          20.215443      1.506171    297.143169      1.498878
# std            6.081771      0.499978    172.453136      0.500014
# min            9.990000      1.000000      1.000000      1.000000
# 25%           14.990000      1.000000    148.000000      1.000000
# 50%           20.990000      2.000000    296.000000      1.000000
# 75%           25.990000      2.000000    446.000000      2.000000
# max           29.990000      2.000000    599.000000      2.000000
#
#          payment_id   customer_id      staff_id        amount    may_target  \
# count  16044.000000  16044.000000  16044.000000  16044.000000  16044.000000
# mean    8024.483732    297.143169      1.498005      4.201356      7.009536
# std     4632.695501    172.453136      0.500012      2.362961      1.034514
# min        1.000000      1.000000      1.000000      0.000000      2.000000
# 25%     4012.750000    148.000000      1.000000      2.990000      7.000000
# 50%     8024.500000    296.000000      1.000000      3.990000      7.000000
# 75%    12036.250000    446.000000      2.000000      4.990000      8.000000
# max    16049.000000    599.000000      2.000000     11.990000      8.000000
#
#        duration_of_rental
# count        16044.000000
# mean             4.531351
# std              2.620519
# min              0.000000
# 25%              2.000000
# 50%              5.000000
# 75%              7.000000
# max              9.000000

# %%
sakila.columns
# Out:
# Index(['rental_id', 'category_id', 'film_id', 'inventory_id', 'title',
#        'description', 'release_year', 'language_id', 'original_language_id',
#        'rental_duration', 'rental_rate', 'length', 'replacement_cost',
#        'rating', 'special_features', 'last_update', 'store_id', 'last_update',
#        'rental_date', 'customer_id', 'return_date', 'staff_id', 'last_update',
#        'last_update', 'name', 'last_update', 'payment_id', 'customer_id',
#        'staff_id', 'amount', 'payment_date', 'last_update', 'may_target',
#        'duration_of_rental'],
#       dtype='object')

# %%
sakila.head(60)
# Out:
#     rental_id  category_id  film_id  inventory_id                title  \
# 0       10895            1       19            93         AMADEUS HOLY
# 1       12268            1       19            93         AMADEUS HOLY
# 2        3150            1       19            94         AMADEUS HOLY
# 3        5072            1       19            94         AMADEUS HOLY
# 4        9080            1       19            94         AMADEUS HOLY
# 5       14603            1       19            94         AMADEUS HOLY
# 6         588            1       19            95         AMADEUS HOLY
# 7        2867            1       19            95         AMADEUS HOLY
# 8        6030            1       19            95         AMADEUS HOLY
# 9        7788            1       19            95         AMADEUS HOLY
# 10      14310            1       19            95         AMADEUS HOLY
# 11      10509            1       19            96         AMADEUS HOLY
# 12      14349            1       19            96         AMADEUS HOLY
# 13       1735            1       19            97         AMADEUS HOLY
# 22            1                 None                3         4.99     129
# 23            1                 None                3         4.99     129
# 24            1                 None                3         4.99     129
# 25            1                 None                3         4.99     129
# 26            1                 None                3         4.99     129
# 27            1                 None                3         4.99     129
# 28            1                 None                3         4.99     129
# 29            1                 None                3         4.99     129
# 30            1                 None                3         4.99     129
# 31            1                 None                3         4.99     129
# 32            1                 None                3         4.99     129
# 33            1                 None                3         4.99     129
# 34            1                 None                3         4.99     129
# 35            1                 None                3         4.99     129
# 36            1                 None                3         4.99     129
# 37            1                 None                3         4.99     129
# 38            1                 None                3         4.99     129
# 39            1                 None                3         4.99     129
# 40            1                 None                3         4.99     129
# 41            1                 None                3         4.99     129
# 42            1                 None                3         4.99     129
# 43            1                 None                5         2.99     168
# 44            1                 None                5         2.99     168
# 45            1                 None                5         2.99     168
# 46            1                 None                5         2.99     168
# 47            1                 None                5         2.99     168
# 48            1                 None                5         2.99     168
# 49            1                 None                5         2.99     168
# 50            1                 None                5         2.99     168
# 51            1                 None                5         2.99     168
# 52            1                 None                5         2.99     168
# 53            1                 None                6         2.99     129
# 54            1                 None                6         2.99     129
# 55            1                 None                6         2.99     129
# 56            1                 None                6         2.99     129
# 57            1                 None                6         2.99     129
# 58            1                 None                6         2.99     129
# 59            1                 None                6         2.99     129
#
#     replacement_cost rating                               special_features  \
# 0              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 1              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 2              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 3              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 4              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 5              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 6              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 7              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 8              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 9              20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 10             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 11             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 12             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 13             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 14             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 15             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 16             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 17             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 18             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 19             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 20             20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# 21             17.99      R                 Commentaries,Behind the Scenes
# 22             17.99      R                 Commentaries,Behind the Scenes
# 23             17.99      R                 Commentaries,Behind the Scenes
# 24             17.99      R                 Commentaries,Behind the Scenes
# 25             17.99      R                 Commentaries,Behind the Scenes
# 26             17.99      R                 Commentaries,Behind the Scenes
# 27             17.99      R                 Commentaries,Behind the Scenes
# 28             17.99      R                 Commentaries,Behind the Scenes
# 29             17.99      R                 Commentaries,Behind the Scenes
# 30             17.99      R                 Commentaries,Behind the Scenes
# 31             17.99      R                 Commentaries,Behind the Scenes
# 32             17.99      R                 Commentaries,Behind the Scenes
# 33             17.99      R                 Commentaries,Behind the Scenes
# 34             17.99      R                 Commentaries,Behind the Scenes
# 35             17.99      R                 Commentaries,Behind the Scenes
# 36             17.99      R                 Commentaries,Behind the Scenes
# 37             17.99      R                 Commentaries,Behind the Scenes
# 38             17.99      R                 Commentaries,Behind the Scenes
# 39             17.99      R                 Commentaries,Behind the Scenes
# 40             17.99      R                 Commentaries,Behind the Scenes
# 41             17.99      R                 Commentaries,Behind the Scenes
# 42             17.99      R                 Commentaries,Behind the Scenes
# 43             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 44             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 45             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 46             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 47             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 48             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 49             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 50             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 51             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 52             11.99  NC-17           Trailers,Commentaries,Deleted Scenes
# 53             15.99      G                          Trailers,Commentaries
# 54             15.99      G                          Trailers,Commentaries
# 55             15.99      G                          Trailers,Commentaries
# 56             15.99      G                          Trailers,Commentaries
# 57             15.99      G                          Trailers,Commentaries
# 58             15.99      G                          Trailers,Commentaries
# 59             15.99      G                          Trailers,Commentaries
#
#            last_update  store_id         last_update         rental_date  \
# 0  2006-02-15 05:03:42         1 2006-02-15 05:09:17 2005-08
# 58         2    3.99 2005-06-18 01:20:26 2006-02-15 22:20:21           0
# 59         2    2.99 2005-07-09 00:30:52 2006-02-15 22:13:37           0
#
#     duration_of_rental
# 0                    1
# 1                    5
# 2                    5
# 3                    9
# 4                    7
# 5                    6
# 6                    1
# 7                    3
# 8                    5
# 9                    5
# 10                   1
# 11                   8
# 12                   9
# 13                   3
# 14                   2
# 15                   7
# 16                   5
# 17                   1
# 18                   2
# 19                   7
# 20                   2
# 21                   1
# 22                   1
# 23                   6
# 24                   2
# 25                   3
# 26                   8
# 27                   8
# 28                   8
# 29                   7
# 30                   1
# 31                   7
# 32                   3
# 33                   8
# 34                   5
# 35                   7
# 36                   9
# 37                   4
# 38                   1
# 39                   6
# 40                   5
# 41                   7
# 42                   0
# 43                   2
# 44                   9
# 45                   7
# 46                   5
# 47                   4
# 48                   1
# 49                   6
# 50                   3
# 51                   5
# 52                   2
# 53                   7
# 54                   4
# 55                   0
# 56                   6
# 57                   9
# 58                   6
# 59                   6

# %%
sakila.columns
# Out:
# Index(['rental_id', 'category_id', 'film_id', 'inventory_id', 'title',
#        'description', 'release_year', 'language_id', 'original_language_id',
#        'rental_duration', 'rental_rate', 'length', 'replacement_cost',
#        'rating', 'special_features', 'last_update', 'store_id', 'last_update',
#        'rental_date', 'customer_id', 'return_date', 'staff_id', 'last_update',
#        'last_update', 'name', 'last_update', 'payment_id', 'customer_id',
#        'staff_id', 'amount', 'payment_date', 'last_update', 'may_target',
#        'duration_of_rental'],
#       dtype='object')

# %%
# The following columns are dropped.
#They do not have an effect on the target feature (may_target).
sakila = sakila.drop(['title','special_features','name','film_id','category_id', 'rental_id', 'inventory_id', 'description', 'release_year', 'language_id', 'original_language_id', 'last_update',
                     'last_update', 'rental_date', 'customer_id', 'return_date', 'staff_id', 'replacement_cost', 'payment_id', 'payment_date','store_id'], axis=1)

# %%
sakila.shape
# Out:
# (16044, 7)

# %%
sakila.dtypes
# Out:
# rental_duration         int64
# rental_rate           float64
# length                  int64
# rating                 object
# amount                float64
# may_target              int64
# duration_of_rental      int64
# dtype: object

# %%
sakila.head()
# Out:
#    rental_duration  rental_rate  length rating  amount  may_target  \
# 0                6         0.99     113     PG    0.99           0
# 1                6         0.99     113     PG    0.99           0
# 2                6         0.99     113     PG    0.99           0
# 3                6         0.99     113     PG    3.99           0
# 4                6         0.99     113     PG    1.99           0
#
#    duration_of_rental
# 0                   1
# 1                   5
# 2                   5
# 3                   9
# 4                   7

# %% [markdown]
# ## Analyze extracted features and transform them. You may need to encode some categorical variables, or scale numerical variables.

# %%
# look for multicolinearity (some columns having almost identical correlation to other variables)
corr_matrix=sakila.corr(method='pearson')  # default
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
sns.displot(sakila['amount'], kde=True) # distribution plot of amount (payment)
plt.show()

sns.displot(sakila['duration_of_rental'], kde=True) # distribution plot of amount (duration_of_rental)
plt.show()

# %%
# from sklearn.preprocessing import StandardScaler

X_num = sakila.select_dtypes(include = np.number)
X_cat = sakila.select_dtypes(include = np.object)

# Scaling data
transformer = MinMaxScaler().fit(X_num)
x_normalized = transformer.transform(X_num)
x_norm = pd.DataFrame(x_normalized, columns=X_num.columns)
x_norm.head()
# Out:
# /var/folders/tr/nqbjf62d721fqy35q732j79m0000gn/T/ipykernel_5860/686408584.py:4: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_cat = sakila.select_dtypes(include = np.object)
#    rental_duration  rental_rate    length    amount  may_target  \
# 0             0.75          0.0  0.482014  0.082569         0.0
# 1             0.75          0.0  0.482014  0.082569         0.0
# 2             0.75          0.0  0.482014  0.082569         0.0
# 3             0.75          0.0  0.482014  0.332777         0.0
# 4             0.75          0.0  0.482014  0.165972         0.0
#
#    duration_of_rental
# 0            0.111111
# 1            0.555556
# 2            0.555556
# 3            1.000000
# 4            0.777778

# %%
# Need to X-y-split AND train-test-split BEFORE I apply transformations, 
# then train transformation on training set only
y = sakila['may_target']
X = sakila.drop('may_target', axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)

# %%
# from sklearn.preprocessing import StandardScaler

X_train_num = X_train.select_dtypes(include = np.number)

# Scaling data
transformer = MinMaxScaler().fit(X_train_num) # need to keep transformer
X_train_normalized = transformer.transform(X_train_num)
X_train_norm = pd.DataFrame(X_train_normalized, columns=X_train_num.columns)
X_train_norm
# Out:
#        rental_duration  rental_rate    length    amount  duration_of_rental
# 0                 1.00          0.0  0.064748  0.082569            0.333333
# 1                 0.50          1.0  0.244604  0.416180            0.555556
# 2                 1.00          0.0  0.460432  0.165972            0.888889
# 3                 0.00          0.0  0.172662  0.249374            0.444444
# 4                 1.00          0.5  0.237410  0.249374            0.555556
# ...                ...          ...       ...       ...                 ...
# 12830             0.00          0.5  0.539568  0.416180            0.444444
# 12831             1.00          1.0  0.856115  0.499583            0.777778
# 12832             0.25          0.5  0.697842  0.249374            0.000000
# 12833             0.75          0.5  0.964029  0.249374            0.222222
# 12834             0.00          0.5  0.539568  0.666389            0.777778
#
# [12835 rows x 5 columns]

# %%
sakila.dtypes
# Out:
# rental_duration         int64
# rental_rate           float64
# length                  int64
# rating                 object
# amount                float64
# may_target              int64
# duration_of_rental      int64
# dtype: object

# %%
X_train_categorical = X_train.select_dtypes(include = np.object)

X_train_categorical
# Out:
# /var/folders/tr/nqbjf62d721fqy35q732j79m0000gn/T/ipykernel_5860/1532212171.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_train_categorical = X_train.select_dtypes(include = np.object)
#       rating
# 15993  NC-17
# 14538     PG
# 174    PG-13
# 6083      PG
# 9178   PG-13
# ...      ...
# 3239      PG
# 9448   PG-13
# 860        R
# 8381   NC-17
# 3223      PG
#
# [12835 rows x 1 columns]

# %%
X_train_cat = pd.get_dummies(X_train_categorical, 
                             columns=['rating'],
                             drop_first=True)
X_train_cat.head()
# Out:
#        rating_NC-17  rating_PG  rating_PG-13  rating_R
# 15993             1          0             0         0
# 14538             0          1             0         0
# 174               0          0             1         0
# 6083              0          1             0         0
# 9178              0          0             1         0

# %%
# build X_train and y_train
# remember: y = data['status'], y_train selected in train_test_split
X_train_transformed = np.concatenate([X_train_norm, X_train_cat], axis=1)

# %%
#array
X_train_transformed
# Out:
# array([[1.        , 0.        , 0.0647482 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.5       , 1.        , 0.24460432, ..., 1.        , 0.        ,
#         0.        ],
#        [1.        , 0.        , 0.46043165, ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.25      , 0.5       , 0.69784173, ..., 0.        , 0.        ,
#         1.        ],
#        [0.75      , 0.5       , 0.96402878, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.5       , 0.53956835, ..., 1.        , 0.        ,
#         0.        ]])

# %% [markdown]
# ## Create a logistic regression model to predict this variable from the cleaned data.

# %%
from sklearn.linear_model import LogisticRegression
classification = LogisticRegression(random_state=0, solver='lbfgs',
                  multi_class='multinomial').fit(X_train_transformed, y_train)

#classifications allow me to predict.

# %%
classification = LogisticRegression(random_state=0, solver='saga',
                  multi_class='multinomial').fit(X_train_transformed, y_train)

# %%
# for numericals
X_test_num = X_test.select_dtypes(include = np.number)

# Scaling data
# we use the transformer that was trained on the training data
X_test_normalized = transformer.transform(X_test_num)
X_test_norm = pd.DataFrame(X_test_normalized)
X_test_norm.shape
# Out:
# (3209, 5)

# %%
# for categoricals
X_test_categorical = X_test.select_dtypes(include = np.object)
X_test_cat = pd.get_dummies(X_test_categorical, 
                            columns=['rating'],
                            drop_first=True)
# verify that dummies columns are in the same order and that the same column was dropped
display(list(zip(list(X_train_cat.columns),list(X_test_cat.columns))))
# not needed if you treat each dataframe with one_hot_encoder and save the encode (and the column names)

X_test_cat.head()
# Out:
# /var/folders/tr/nqbjf62d721fqy35q732j79m0000gn/T/ipykernel_5860/579139423.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_test_categorical = X_test.select_dtypes(include = np.object)
# [('rating_NC-17', 'rating_NC-17'),
#  ('rating_PG', 'rating_PG'),
#  ('rating_PG-13', 'rating_PG-13'),
#  ('rating_R', 'rating_R')]
#        rating_NC-17  rating_PG  rating_PG-13  rating_R
# 15533             0          0             0         1
# 13122             1          0             0         0
# 10796             0          0             1         0
# 3197              0          0             1         0
# 3084              1          0             0         0

# %%
X.shape
# Out:
# (16044, 6)

# %%
X_test_norm.shape
# Out:
# (3209, 5)

# %%
X_test_cat.shape
# Out:
# (3209, 4)

# %%
X_test_transformed = np.concatenate([X_test_norm, X_test_cat], axis=1)

# %%
predictions = classification.predict(X_test_transformed)
predictions
classification.score(X_test_transformed, y_test)
# Out:
# 0.9267684636958554

# %%
print(y_test.value_counts())
# As you would notice here, there is a huge imbalance in the data among the different classes. 
# We will talk more about imbalance and how to resolve it later (tomorrow)
# Out:
# 0    2974
# 1     235
# Name: may_target, dtype: int64

# %%
pd.Series(predictions).value_counts()
# This shows that the disparity in the numbers are amplified by the model
# Out:
# 0    3209
# dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)

# number of times of predictions
# Out:
# array([[2974,    0],
#        [ 235,    0]])

# %%
# KNN classifier: look at nearest neighbours and use the majority to determine class
from sklearn import neighbors
clf = neighbors.KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train_transformed, y_train)
predictions_clf = clf.predict(X_test_transformed)
clf.score(X_test_transformed, y_test)
# Out:
# 0.9258335930196323

# %%
confusion_matrix(y_test, predictions_clf)
# Out:
# array([[2971,    3],
#        [ 235,    0]])

# %%
pd.Series(y_test).value_counts()
# Out:
# 0    2974
# 1     235
# Name: may_target, dtype: int64

# %%
pd.Series(predictions_clf).value_counts()
# Out:
# 0    3206
# 1       3
# dtype: int64

# %% [markdown]
# ## Evaluate the results.

# %%
# The target feature is may_target. The logistic regression model is applied to predict how many 
# films to be rented in the following months after May. The predictions indicate a score of 0.93. KNN classifier also results in 0.93 score. 
# These results imply that the model predicts accurately.
